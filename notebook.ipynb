# %% [markdown]
# ## Import libraries

# %%
import isthmuslib
import numpy as np

# %% [markdown]
# ## Make species

# %%
np.random.seed(0)
species_1: np.ndarray = [x/30 + 0.3 for x in np.random.normal(size=10000)]
species_2: np.ndarray = [x/40 + 0.8 for x in np.random.normal(size=10000)]

# %% [markdown]
# ## Make plots

# %%
isthmuslib.hist([pop1, pop2], bins = 250, density=True, xlim=[0,1], grid=False, figsize=(12,8), facecolor=None)
isthmuslib.plt.ylabel('')
# Out:
# Text(0, 0.5, '')
